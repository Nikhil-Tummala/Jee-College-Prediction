# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import pandas as pd
import pickle

# %%
final_df=pickle.load(open("data_v1.pkl","rb"))

# %%
final_df
# Out:
#                                          Institute  \
# 0       Indian Institute of Technology Bhubaneswar
# 1       Indian Institute of Technology Bhubaneswar
# 2       Indian Institute of Technology Bhubaneswar
# 3       Indian Institute of Technology Bhubaneswar
# 4       Indian Institute of Technology Bhubaneswar
# ...                                            ...
# 443331                                CU Jharkhand
# 443332                                CU Jharkhand
# 443333                                CU Jharkhand
# 443334                                CU Jharkhand
# 443335                                CU Jharkhand
#
#                                     Academic Program Name Quota Seat Type  \
# 0       Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1       Civil Engineering (4 Years, Bachelor of Techno...    AI   OBC-NCL
# 2       Civil Engineering (4 Years, Bachelor of Techno...    AI        SC
# 3       Civil Engineering (4 Years, Bachelor of Techno...    AI        ST
# 4       Civil Engineering and M. Tech. in Structural E...    AI      OPEN
# ...                                                   ...   ...       ...
# 443331  Integrated B. Tech.- M. Tech in Metallurgical ...    AI      OPEN
# 443332  Integrated B. Tech.- M. Tech in Metallurgical ...    AI       EWS
# 443333  Integrated B. Tech.- M. Tech in Metallurgical ...    AI   OBC-NCL
# 443334  Integrated B. Tech.- M. Tech in Metallurgical ...    AI        SC
# 443335  Integrated B. Tech.- M. Tech in Metallurgical ...    AI        ST
#
#          Gender Opening Rank Closing Rank  year  round
# 0       Neutral       3533.0       5947.0  2016      1
# 1       Neutral       1829.0       2213.0  2016      1
# 2       Neutral        663.0       1023.0  2016      1
# 3       Neutral        331.0        357.0  2016      1
# 4       Neutral       5408.0       6561.0  2016      1
# ...         ...          ...          ...   ...    ...
# 443331  Neutral        91148       111567  2024      6
# 443332  Neutral        18667        18876  2024      6
# 443333  Neutral        37570        39002  2024      6
# 443334  Neutral        16473        17172  2024      6
# 443335  Neutral         6278         8144  2024      6
#
# [443288 rows x 9 columns]

# %%
final_df=final_df.dropna(subset=["Institute"])

# %%
final_df["Gender"]=final_df["Gender"].fillna("Neutral")

# %%
final_df["Gender"].value_counts()
# Out:
# Gender
# Neutral    297288
# Female     146000
# Name: count, dtype: int64

# %%
def clean_rank(value):
    try:
        return int(float(value))
    except ValueError:
        return int(value[:-1]) if value[:-1].isdigit() else np.nan

# %%
final_df['Opening Rank'] = final_df['Opening Rank'].apply(clean_rank)

# %%
final_df['Closing Rank'] = final_df['Closing Rank'].apply(clean_rank)

# %%
with open("data_v2.pkl","wb") as f:
    pickle.dump(final_df,f)

# %%
final_df=pickle.load(open("data_v2.pkl","rb"))

# %%
X = final_df[['Opening Rank', 'Gender', 'Seat Type']]
y = final_df[['Institute', 'round']]


categorical_features = ['Gender', 'Seat Type']
numeric_features = ['Opening Rank']

# %%
le_institute = LabelEncoder()
final_df["Institute"]=le_institute.fit_transform(final_df['Institute'])

# %%
x
# Out:
# array([51, 51, 51, ...,  5,  5,  5])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# %%
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', MultiOutputClassifier(RandomForestClassifier(n_estimators=100, random_state=42)))
])

# %%
train_data = final_df[final_df['year'] < final_df['year'].max()]
test_data = final_df[final_df['year'] == final_df['year'].max()]

# %%
X_train = train_data[['Opening Rank', 'Gender', 'Seat Type']]
y_train = train_data[['Institute', 'round']]
X_test = test_data[['Opening Rank', 'Gender', 'Seat Type']]
y_test = test_data[['Institute', 'round']]

# %%
test_data
# Out:
#         Institute                              Academic Program Name Quota  \
# 375162         51  Civil Engineering (4 Years, Bachelor of Techno...    AI
# 375163         51  Civil Engineering (4 Years, Bachelor of Techno...    AI
# 375164         51  Civil Engineering (4 Years, Bachelor of Techno...    AI
# 375165         51  Civil Engineering (4 Years, Bachelor of Techno...    AI
# 375166         51  Civil Engineering (4 Years, Bachelor of Techno...    AI
# ...           ...                                                ...   ...
# 443331          5  Integrated B. Tech.- M. Tech in Metallurgical ...    AI
# 443332          5  Integrated B. Tech.- M. Tech in Metallurgical ...    AI
# 443333          5  Integrated B. Tech.- M. Tech in Metallurgical ...    AI
# 443334          5  Integrated B. Tech.- M. Tech in Metallurgical ...    AI
# 443335          5  Integrated B. Tech.- M. Tech in Metallurgical ...    AI
#
#        Seat Type   Gender  Opening Rank  Closing Rank  year  round
# 375162      OPEN  Neutral          9106         13018  2024      1
# 375163      OPEN   Female         18286         20788  2024      1
# 375164       EWS  Neutral          1755          1975  2024      1
# 375165       EWS   Female          3122          3308  2024      1
# 375166   OBC-NCL  Neutral          3573          4796  2024      1
# ...          ...      ...           ...           ...   ...    ...
# 443331      OPEN  Neutral         91148        111567  2024      6
# 443332       EWS  Neutral         18667         18876  2024      6
# 443333   OBC-NCL  Neutral         37570         39002  2024      6
# 443334        SC  Neutral         16473         17172  2024      6
# 443335        ST  Neutral          6278          8144  2024      6
#
# [68174 rows x 9 columns]

# %%
import gc

# Clear variables
del model
gc.collect()

# Now try loading the model again
import joblib
model = joblib.load('jee_model.joblib')
